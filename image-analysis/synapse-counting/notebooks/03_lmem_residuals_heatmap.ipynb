# %% [markdown]
# ## Plotting the synaptic metric residuals in a cluster heatmap across hemispheres and brains
# #### Input: output of `02_lmem_residuals_pca.R`
# #### Description:
# #####   (1) data scaling
# #####   (2) data frame operations
# #####   (3) plotting the heatmap
# #### Date: Nov 2025

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
# arguments
protein = "GPR37L1"

# %%
# loading the data
residuals = f"/Volumes/Intenso/image-analysis/synapse-counting/results_202512/{protein}_lmem_residuals_results.csv"
residuals_df = pd.read_csv(residuals, index_col=0)
residuals_df.rename_axis("sample_ID")
# Out:
#                       residual_VGLUT1_PSD95_CA1_SLM_local_peak_colocalized_spots  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                           0.027267
# GPR37L1-gRNA_Brain-3                                           0.259617
# GPR37L1-gRNA_Brain-4                                           0.313006
# GPR37L1-gRNA_Brain-6                                           0.118059
# LacZ-gRNA_Brain-2                                             -0.005502
# LacZ-gRNA_Brain-3                                             -0.315421
# LacZ-gRNA_Brain-4                                             -0.312650
# LacZ-gRNA_Brain-6                                             -0.084375
#
#                       residual_VGLUT1_PSD95_CA1_SLM_overlap_coeff  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                    -0.000076
# GPR37L1-gRNA_Brain-3                                    -0.025041
# GPR37L1-gRNA_Brain-4                                    -0.006886
# GPR37L1-gRNA_Brain-6                                    -0.003792
# LacZ-gRNA_Brain-2                                        0.006277
# LacZ-gRNA_Brain-3                                        0.029539
# LacZ-gRNA_Brain-4                                       -0.010195
# LacZ-gRNA_Brain-6                                        0.010175
#
#                       residual_VGLUT1_PSD95_CA1_SLM_overlap_um2  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                  -0.033047
# GPR37L1-gRNA_Brain-3                                  -0.186356
# GPR37L1-gRNA_Brain-4                                  -0.162507
# GPR37L1-gRNA_Brain-6                                  -0.055358
# LacZ-gRNA_Brain-2                                      0.076827
# LacZ-gRNA_Brain-3                                      0.270565
# LacZ-gRNA_Brain-4                                      0.016437
# LacZ-gRNA_Brain-6                                      0.073439
#
#                       residual_VGLUT1_PSD95_CA1_SLM_pearson_cor  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                   0.005063
# GPR37L1-gRNA_Brain-3                                  -0.026215
# GPR37L1-gRNA_Brain-4                                   0.012245
# GPR37L1-gRNA_Brain-6                                  -0.003657
# LacZ-gRNA_Brain-2                                      0.001439
# LacZ-gRNA_Brain-3                                      0.018845
# LacZ-gRNA_Brain-4                                     -0.024684
# LacZ-gRNA_Brain-6                                      0.016964
#
#                       residual_VGLUT1_PSD95_CA1_SLM_presynapse_image_mfi  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                          -0.089817
# GPR37L1-gRNA_Brain-3                                          -0.094704
# GPR37L1-gRNA_Brain-4                                          -0.028389
# GPR37L1-gRNA_Brain-6                                          -0.030139
# LacZ-gRNA_Brain-2                                              0.108636
# LacZ-gRNA_Brain-3                                              0.065381
# LacZ-gRNA_Brain-4                                              0.022485
# LacZ-gRNA_Brain-6                                              0.046547
#
#                       residual_VGLUT1_PSD95_CA1_SLM_postsynapse_image_mfi  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                           0.018749
# GPR37L1-gRNA_Brain-3                                           0.107039
# GPR37L1-gRNA_Brain-4                                          -0.033332
# GPR37L1-gRNA_Brain-6                                           0.057990
# LacZ-gRNA_Brain-2                                             -0.007183
# LacZ-gRNA_Brain-3                                             -0.154799
# LacZ-gRNA_Brain-4                                              0.022996
# LacZ-gRNA_Brain-6                                             -0.011459
#
#                       residual_VGLUT1_PSD95_CA1_SLM_pre_puncta_density_per_100_um2  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                          -0.042766
# GPR37L1-gRNA_Brain-3                                          -0.039832
# GPR37L1-gRNA_Brain-4                                          -0.065653
# GPR37L1-gRNA_Brain-6                                          -0.013500
# LacZ-gRNA_Brain-2                                              0.020272
# LacZ-gRNA_Brain-3                                              0.106606
# LacZ-gRNA_Brain-4                                              0.035772
# LacZ-gRNA_Brain-6                                             -0.000899
#
#                       residual_VGLUT1_PSD95_CA1_SLM_post_puncta_density_per_100_um2  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                          -0.033484
# GPR37L1-gRNA_Brain-3                                           0.004468
# GPR37L1-gRNA_Brain-4                                          -0.198787
# GPR37L1-gRNA_Brain-6                                          -0.026570
# LacZ-gRNA_Brain-2                                              0.050099
# LacZ-gRNA_Brain-3                                              0.082466
# LacZ-gRNA_Brain-4                                              0.123425
# LacZ-gRNA_Brain-6                                             -0.001616
#
#                       residual_VGLUT1_PSD95_CA1_SLM_pre_staining_area_um2  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                          -0.023652
# GPR37L1-gRNA_Brain-3                                          -0.109295
# GPR37L1-gRNA_Brain-4                                          -0.117167
# GPR37L1-gRNA_Brain-6                                          -0.021655
# LacZ-gRNA_Brain-2                                              0.059576
# LacZ-gRNA_Brain-3                                              0.215075
# LacZ-gRNA_Brain-4                                             -0.039746
# LacZ-gRNA_Brain-6                                              0.036864
#
#                       residual_VGLUT1_PSD95_CA1_SLM_post_staining_area_um2  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                          -0.030391
# GPR37L1-gRNA_Brain-3                                          -0.019529
# GPR37L1-gRNA_Brain-4                                          -0.184930
# GPR37L1-gRNA_Brain-6                                          -0.050253
# LacZ-gRNA_Brain-2                                              0.046518
# LacZ-gRNA_Brain-3                                              0.093302
# LacZ-gRNA_Brain-4                                              0.116490
# LacZ-gRNA_Brain-6                                              0.028792
#
#                       ...  residual_VGAT_GEPH_DG_ML_overlap_um2  \
# sample_ID             ...
# GPR37L1-gRNA_Brain-2  ...                             -0.084367
# GPR37L1-gRNA_Brain-3  ...                             -0.391993
# GPR37L1-gRNA_Brain-4  ...                              0.892890
# GPR37L1-gRNA_Brain-6  ...                             -0.111490
# LacZ-gRNA_Brain-2     ...                              0.154296
# LacZ-gRNA_Brain-3     ...                             -0.643726
# LacZ-gRNA_Brain-4     ...                             -0.401524
# LacZ-gRNA_Brain-6     ...                              0.585912
#
#                       residual_VGAT_GEPH_DG_ML_pearson_cor  \
# sample_ID
# GPR37L1-gRNA_Brain-2                             -0.010186
# GPR37L1-gRNA_Brain-3                             -0.011552
# GPR37L1-gRNA_Brain-4                              0.007466
# GPR37L1-gRNA_Brain-6                             -0.010675
# LacZ-gRNA_Brain-2                                 0.014186
# LacZ-gRNA_Brain-3                                 0.007055
# LacZ-gRNA_Brain-4                                -0.010778
# LacZ-gRNA_Brain-6                                 0.014484
#
#                       residual_VGAT_GEPH_DG_ML_presynapse_image_mfi  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                      -0.071697
# GPR37L1-gRNA_Brain-3                                      -0.160389
# GPR37L1-gRNA_Brain-4                                       0.019437
# GPR37L1-gRNA_Brain-6                                      -0.061884
# LacZ-gRNA_Brain-2                                          0.127780
# LacZ-gRNA_Brain-3                                          0.057645
# LacZ-gRNA_Brain-4                                         -0.023816
# LacZ-gRNA_Brain-6                                          0.112925
#
#                       residual_VGAT_GEPH_DG_ML_postsynapse_image_mfi  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                       -0.006304
# GPR37L1-gRNA_Brain-3                                       -0.089446
# GPR37L1-gRNA_Brain-4                                       -0.000655
# GPR37L1-gRNA_Brain-6                                       -0.058428
# LacZ-gRNA_Brain-2                                           0.017402
# LacZ-gRNA_Brain-3                                           0.066466
# LacZ-gRNA_Brain-4                                          -0.006396
# LacZ-gRNA_Brain-6                                           0.077361
#
#                       residual_VGAT_GEPH_DG_ML_pre_puncta_density_per_100_um2  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                           0.520083
# GPR37L1-gRNA_Brain-3                                          -0.301591
# GPR37L1-gRNA_Brain-4                                           0.479528
# GPR37L1-gRNA_Brain-6                                           0.258575
# LacZ-gRNA_Brain-2                                              0.244072
# LacZ-gRNA_Brain-3                                             -0.377183
# LacZ-gRNA_Brain-4                                             -1.302216
# LacZ-gRNA_Brain-6                                              0.478731
#
#                       residual_VGAT_GEPH_DG_ML_post_puncta_density_per_100_um2  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                          -0.336773
# GPR37L1-gRNA_Brain-3                                           0.154822
# GPR37L1-gRNA_Brain-4                                          -0.081049
# GPR37L1-gRNA_Brain-6                                          -0.246576
# LacZ-gRNA_Brain-2                                              0.114351
# LacZ-gRNA_Brain-3                                             -0.124541
# LacZ-gRNA_Brain-4                                              0.330350
# LacZ-gRNA_Brain-6                                              0.189416
#
#                       residual_VGAT_GEPH_DG_ML_pre_staining_area_um2  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                        0.581240
# GPR37L1-gRNA_Brain-3                                       -0.443810
# GPR37L1-gRNA_Brain-4                                        0.645315
# GPR37L1-gRNA_Brain-6                                        0.234503
# LacZ-gRNA_Brain-2                                           0.271233
# LacZ-gRNA_Brain-3                                          -0.544537
# LacZ-gRNA_Brain-4                                          -1.303146
# LacZ-gRNA_Brain-6                                           0.559202
#
#                       residual_VGAT_GEPH_DG_ML_post_staining_area_um2  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                        -0.396380
# GPR37L1-gRNA_Brain-3                                         0.172309
# GPR37L1-gRNA_Brain-4                                        -0.130941
# GPR37L1-gRNA_Brain-6                                        -0.303616
# LacZ-gRNA_Brain-2                                            0.165749
# LacZ-gRNA_Brain-3                                           -0.161027
# LacZ-gRNA_Brain-4                                            0.421315
# LacZ-gRNA_Brain-6                                            0.232591
#
#                       residual_VGAT_GEPH_DG_ML_pre_mean_puncta_size_um2  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                           0.001723
# GPR37L1-gRNA_Brain-3                                          -0.000920
# GPR37L1-gRNA_Brain-4                                           0.006116
# GPR37L1-gRNA_Brain-6                                          -0.003648
# LacZ-gRNA_Brain-2                                             -0.000914
# LacZ-gRNA_Brain-3                                             -0.002670
# LacZ-gRNA_Brain-4                                             -0.003814
# LacZ-gRNA_Brain-6                                              0.004126
#
#                       residual_VGAT_GEPH_DG_ML_post_mean_puncta_size_um2
# sample_ID
# GPR37L1-gRNA_Brain-2                                          -0.005504
# GPR37L1-gRNA_Brain-3                                           0.002079
# GPR37L1-gRNA_Brain-4                                          -0.004644
# GPR37L1-gRNA_Brain-6                                          -0.004154
# LacZ-gRNA_Brain-2                                              0.003578
# LacZ-gRNA_Brain-3                                             -0.002569
# LacZ-gRNA_Brain-4                                              0.007903
# LacZ-gRNA_Brain-6                                              0.003311
#
# [8 rows x 192 columns]

# %%
# scaling the data
scaler = StandardScaler()
scaled_residuals = scaler.fit_transform(residuals_df)

# put back into df
scaled_residuals_df = pd.DataFrame(data=scaled_residuals,
                     columns=residuals_df.columns,
                     index=residuals_df.index)
scaled_residuals_df = scaled_residuals_df.rename_axis("sample_ID")
scaled_residuals_df
# Out:
#                       residual_VGLUT1_PSD95_CA1_SLM_local_peak_colocalized_spots  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                           0.124384
# GPR37L1-gRNA_Brain-3                                           1.184298
# GPR37L1-gRNA_Brain-4                                           1.427842
# GPR37L1-gRNA_Brain-6                                           0.538552
# LacZ-gRNA_Brain-2                                             -0.025099
# LacZ-gRNA_Brain-3                                             -1.438860
# LacZ-gRNA_Brain-4                                             -1.426220
# LacZ-gRNA_Brain-6                                             -0.384896
#
#                       residual_VGLUT1_PSD95_CA1_SLM_overlap_coeff  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                    -0.005053
# GPR37L1-gRNA_Brain-3                                    -1.665596
# GPR37L1-gRNA_Brain-4                                    -0.458005
# GPR37L1-gRNA_Brain-6                                    -0.252242
# LacZ-gRNA_Brain-2                                        0.417514
# LacZ-gRNA_Brain-3                                        1.964744
# LacZ-gRNA_Brain-4                                       -0.678115
# LacZ-gRNA_Brain-6                                        0.676753
#
#                       residual_VGLUT1_PSD95_CA1_SLM_overlap_um2  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                  -0.241287
# GPR37L1-gRNA_Brain-3                                  -1.360659
# GPR37L1-gRNA_Brain-4                                  -1.186526
# GPR37L1-gRNA_Brain-6                                  -0.404193
# LacZ-gRNA_Brain-2                                      0.560943
# LacZ-gRNA_Brain-3                                      1.975498
# LacZ-gRNA_Brain-4                                      0.120015
# LacZ-gRNA_Brain-6                                      0.536209
#
#                       residual_VGLUT1_PSD95_CA1_SLM_pearson_cor  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                   0.310256
# GPR37L1-gRNA_Brain-3                                  -1.606417
# GPR37L1-gRNA_Brain-4                                   0.750341
# GPR37L1-gRNA_Brain-6                                  -0.224115
# LacZ-gRNA_Brain-2                                      0.088160
# LacZ-gRNA_Brain-3                                      1.154817
# LacZ-gRNA_Brain-4                                     -1.512583
# LacZ-gRNA_Brain-6                                      1.039541
#
#                       residual_VGLUT1_PSD95_CA1_SLM_presynapse_image_mfi  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                          -1.311886
# GPR37L1-gRNA_Brain-3                                          -1.383264
# GPR37L1-gRNA_Brain-4                                          -0.414649
# GPR37L1-gRNA_Brain-6                                          -0.440209
# LacZ-gRNA_Brain-2                                              1.586747
# LacZ-gRNA_Brain-3                                              0.954970
# LacZ-gRNA_Brain-4                                              0.328425
# LacZ-gRNA_Brain-6                                              0.679868
#
#                       residual_VGLUT1_PSD95_CA1_SLM_postsynapse_image_mfi  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                           0.262031
# GPR37L1-gRNA_Brain-3                                           1.495964
# GPR37L1-gRNA_Brain-4                                          -0.465848
# GPR37L1-gRNA_Brain-6                                           0.810469
# LacZ-gRNA_Brain-2                                             -0.100390
# LacZ-gRNA_Brain-3                                             -2.163455
# LacZ-gRNA_Brain-4                                              0.321386
# LacZ-gRNA_Brain-6                                             -0.160157
#
#                       residual_VGLUT1_PSD95_CA1_SLM_pre_puncta_density_per_100_um2  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                          -0.835410
# GPR37L1-gRNA_Brain-3                                          -0.778107
# GPR37L1-gRNA_Brain-4                                          -1.282505
# GPR37L1-gRNA_Brain-6                                          -0.263717
# LacZ-gRNA_Brain-2                                              0.395998
# LacZ-gRNA_Brain-3                                              2.082511
# LacZ-gRNA_Brain-4                                              0.698785
# LacZ-gRNA_Brain-6                                             -0.017555
#
#                       residual_VGLUT1_PSD95_CA1_SLM_post_puncta_density_per_100_um2  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                          -0.368898
# GPR37L1-gRNA_Brain-3                                           0.049220
# GPR37L1-gRNA_Brain-4                                          -2.190064
# GPR37L1-gRNA_Brain-6                                          -0.292728
# LacZ-gRNA_Brain-2                                              0.551945
# LacZ-gRNA_Brain-3                                              0.908539
# LacZ-gRNA_Brain-4                                              1.359787
# LacZ-gRNA_Brain-6                                             -0.017801
#
#                       residual_VGLUT1_PSD95_CA1_SLM_pre_staining_area_um2  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                          -0.237341
# GPR37L1-gRNA_Brain-3                                          -1.096748
# GPR37L1-gRNA_Brain-4                                          -1.175739
# GPR37L1-gRNA_Brain-6                                          -0.217303
# LacZ-gRNA_Brain-2                                              0.597831
# LacZ-gRNA_Brain-3                                              2.158221
# LacZ-gRNA_Brain-4                                             -0.398838
# LacZ-gRNA_Brain-6                                              0.369917
#
#                       residual_VGLUT1_PSD95_CA1_SLM_post_staining_area_um2  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                          -0.341663
# GPR37L1-gRNA_Brain-3                                          -0.219548
# GPR37L1-gRNA_Brain-4                                          -2.079020
# GPR37L1-gRNA_Brain-6                                          -0.564951
# LacZ-gRNA_Brain-2                                              0.522966
# LacZ-gRNA_Brain-3                                              1.048918
# LacZ-gRNA_Brain-4                                              1.309608
# LacZ-gRNA_Brain-6                                              0.323690
#
#                       ...  residual_VGAT_GEPH_DG_ML_overlap_um2  \
# sample_ID             ...
# GPR37L1-gRNA_Brain-2  ...                             -0.172520
# GPR37L1-gRNA_Brain-3  ...                             -0.801580
# GPR37L1-gRNA_Brain-4  ...                              1.825858
# GPR37L1-gRNA_Brain-6  ...                             -0.227985
# LacZ-gRNA_Brain-2     ...                              0.315518
# LacZ-gRNA_Brain-3     ...                             -1.316345
# LacZ-gRNA_Brain-4     ...                             -0.821070
# LacZ-gRNA_Brain-6     ...                              1.198124
#
#                       residual_VGAT_GEPH_DG_ML_pearson_cor  \
# sample_ID
# GPR37L1-gRNA_Brain-2                             -0.918540
# GPR37L1-gRNA_Brain-3                             -1.041670
# GPR37L1-gRNA_Brain-4                              0.673212
# GPR37L1-gRNA_Brain-6                             -0.962583
# LacZ-gRNA_Brain-2                                 1.279233
# LacZ-gRNA_Brain-3                                 0.636136
# LacZ-gRNA_Brain-4                                -0.971856
# LacZ-gRNA_Brain-6                                 1.306069
#
#                       residual_VGAT_GEPH_DG_ML_presynapse_image_mfi  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                      -0.777426
# GPR37L1-gRNA_Brain-3                                      -1.739119
# GPR37L1-gRNA_Brain-4                                       0.210753
# GPR37L1-gRNA_Brain-6                                      -0.671015
# LacZ-gRNA_Brain-2                                          1.385536
# LacZ-gRNA_Brain-3                                          0.625053
# LacZ-gRNA_Brain-4                                         -0.258244
# LacZ-gRNA_Brain-6                                          1.224461
#
#                       residual_VGAT_GEPH_DG_ML_postsynapse_image_mfi  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                       -0.119670
# GPR37L1-gRNA_Brain-3                                       -1.697948
# GPR37L1-gRNA_Brain-4                                       -0.012434
# GPR37L1-gRNA_Brain-6                                       -1.109121
# LacZ-gRNA_Brain-2                                           0.330341
# LacZ-gRNA_Brain-3                                           1.261713
# LacZ-gRNA_Brain-4                                          -0.121406
# LacZ-gRNA_Brain-6                                           1.468524
#
#                       residual_VGAT_GEPH_DG_ML_pre_puncta_density_per_100_um2  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                           0.881459
# GPR37L1-gRNA_Brain-3                                          -0.511149
# GPR37L1-gRNA_Brain-4                                           0.812725
# GPR37L1-gRNA_Brain-6                                           0.438244
# LacZ-gRNA_Brain-2                                              0.413664
# LacZ-gRNA_Brain-3                                             -0.639265
# LacZ-gRNA_Brain-4                                             -2.207051
# LacZ-gRNA_Brain-6                                              0.811373
#
#                       residual_VGAT_GEPH_DG_ML_post_puncta_density_per_100_um2  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                          -1.548585
# GPR37L1-gRNA_Brain-3                                           0.711917
# GPR37L1-gRNA_Brain-4                                          -0.372687
# GPR37L1-gRNA_Brain-6                                          -1.133832
# LacZ-gRNA_Brain-2                                              0.525822
# LacZ-gRNA_Brain-3                                             -0.572676
# LacZ-gRNA_Brain-4                                              1.519050
# LacZ-gRNA_Brain-6                                              0.870992
#
#                       residual_VGAT_GEPH_DG_ML_pre_staining_area_um2  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                        0.893262
# GPR37L1-gRNA_Brain-3                                       -0.682056
# GPR37L1-gRNA_Brain-4                                        0.991734
# GPR37L1-gRNA_Brain-6                                        0.360390
# LacZ-gRNA_Brain-2                                           0.416837
# LacZ-gRNA_Brain-3                                          -0.836856
# LacZ-gRNA_Brain-4                                          -2.002705
# LacZ-gRNA_Brain-6                                           0.859394
#
#                       residual_VGAT_GEPH_DG_ML_post_staining_area_um2  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                        -1.470672
# GPR37L1-gRNA_Brain-3                                         0.639312
# GPR37L1-gRNA_Brain-4                                        -0.485823
# GPR37L1-gRNA_Brain-6                                        -1.126491
# LacZ-gRNA_Brain-2                                            0.614971
# LacZ-gRNA_Brain-3                                           -0.597452
# LacZ-gRNA_Brain-4                                            1.563184
# LacZ-gRNA_Brain-6                                            0.862971
#
#                       residual_VGAT_GEPH_DG_ML_pre_mean_puncta_size_um2  \
# sample_ID
# GPR37L1-gRNA_Brain-2                                           0.502540
# GPR37L1-gRNA_Brain-3                                          -0.268169
# GPR37L1-gRNA_Brain-4                                           1.783695
# GPR37L1-gRNA_Brain-6                                          -1.063822
# LacZ-gRNA_Brain-2                                             -0.266637
# LacZ-gRNA_Brain-3                                             -0.778569
# LacZ-gRNA_Brain-4                                             -1.112287
# LacZ-gRNA_Brain-6                                              1.203249
#
#                       residual_VGAT_GEPH_DG_ML_post_mean_puncta_size_um2
# sample_ID
# GPR37L1-gRNA_Brain-2                                          -1.207346
# GPR37L1-gRNA_Brain-3                                           0.455972
# GPR37L1-gRNA_Brain-4                                          -1.018579
# GPR37L1-gRNA_Brain-6                                          -0.911289
# LacZ-gRNA_Brain-2                                              0.784758
# LacZ-gRNA_Brain-3                                             -0.563517
# LacZ-gRNA_Brain-4                                              1.733616
# LacZ-gRNA_Brain-6                                              0.726384
#
# [8 rows x 192 columns]

# %%
# order to show the heatmap
pair_order = ["VGLUT1_PSD95", "VGAT_GEPH"]

layer_order = [
    "CA1_SO", "CA1_SR", "CA1_SLM",
    "CA3_SO", "CA3_SL", "CA3_SR",
    "DG_ML", "DG_Hilus"
]

metric_order = [
    "presynapse_image_mfi",
    "pre_staining_area_um2",
    "pre_puncta_density_per_100_um2",
    "pre_mean_puncta_size_um2",
    "postsynapse_image_mfi",
    "post_staining_area_um2",
    "post_puncta_density_per_100_um2",
    "post_mean_puncta_size_um2",
    "local_peak_colocalized_spots",
    "pearson_cor",
    "overlap_coeff",
    "overlap_um2"
]

# %%
def extract_keys(col):
    pair = next((p for p in pair_order if p in col), None)
    layer = next((l for l in layer_order if l in col), None)
    metric = next((m for m in metric_order if m in col), None)

    pair_idx = pair_order.index(pair) if pair in pair_order else len(pair_order)
    layer_idx = layer_order.index(layer) if layer in layer_order else len(layer_order)
    metric_idx = metric_order.index(metric) if metric in metric_order else len(metric_order)

    return (pair_idx, layer_idx, metric_idx)

# %%
sorted_cols = sorted(scaled_residuals_df.columns, key=extract_keys)

scaled_residuals_df = scaled_residuals_df.loc[:, sorted_cols]
sorted_cols
# Out:
# ['residual_VGLUT1_PSD95_CA1_SO_presynapse_image_mfi',
#  'residual_VGLUT1_PSD95_CA1_SO_pre_staining_area_um2',
#  'residual_VGLUT1_PSD95_CA1_SO_pre_puncta_density_per_100_um2',
#  'residual_VGLUT1_PSD95_CA1_SO_pre_mean_puncta_size_um2',
#  'residual_VGLUT1_PSD95_CA1_SO_postsynapse_image_mfi',
#  'residual_VGLUT1_PSD95_CA1_SO_post_staining_area_um2',
#  'residual_VGLUT1_PSD95_CA1_SO_post_puncta_density_per_100_um2',
#  'residual_VGLUT1_PSD95_CA1_SO_post_mean_puncta_size_um2',
#  'residual_VGLUT1_PSD95_CA1_SO_local_peak_colocalized_spots',
#  'residual_VGLUT1_PSD95_CA1_SO_pearson_cor',
#  'residual_VGLUT1_PSD95_CA1_SO_overlap_coeff',
#  'residual_VGLUT1_PSD95_CA1_SO_overlap_um2',
#  'residual_VGLUT1_PSD95_CA1_SR_presynapse_image_mfi',
#  'residual_VGLUT1_PSD95_CA1_SR_pre_staining_area_um2',
#  'residual_VGLUT1_PSD95_CA1_SR_pre_puncta_density_per_100_um2',
#  'residual_VGLUT1_PSD95_CA1_SR_pre_mean_puncta_size_um2',
#  'residual_VGLUT1_PSD95_CA1_SR_postsynapse_image_mfi',
#  'residual_VGLUT1_PSD95_CA1_SR_post_staining_area_um2',
#  'residual_VGLUT1_PSD95_CA1_SR_post_puncta_density_per_100_um2',
#  'residual_VGLUT1_PSD95_CA1_SR_post_mean_puncta_size_um2',
#  'residual_VGLUT1_PSD95_CA1_SR_local_peak_colocalized_spots',
#  'residual_VGLUT1_PSD95_CA1_SR_pearson_cor',
#  'residual_VGLUT1_PSD95_CA1_SR_overlap_coeff',
#  'residual_VGLUT1_PSD95_CA1_SR_overlap_um2',
#  'residual_VGLUT1_PSD95_CA1_SLM_presynapse_image_mfi',
#  'residual_VGLUT1_PSD95_CA1_SLM_pre_staining_area_um2',
#  'residual_VGLUT1_PSD95_CA1_SLM_pre_puncta_density_per_100_um2',
#  'residual_VGLUT1_PSD95_CA1_SLM_pre_mean_puncta_size_um2',
#  'residual_VGLUT1_PSD95_CA1_SLM_postsynapse_image_mfi',
#  'residual_VGLUT1_PSD95_CA1_SLM_post_staining_area_um2',
#  'residual_VGLUT1_PSD95_CA1_SLM_post_puncta_density_per_100_um2',
#  'residual_VGLUT1_PSD95_CA1_SLM_post_mean_puncta_size_um2',
#  'residual_VGLUT1_PSD95_CA1_SLM_local_peak_colocalized_spots',
#  'residual_VGLUT1_PSD95_CA1_SLM_pearson_cor',
#  'residual_VGLUT1_PSD95_CA1_SLM_overlap_coeff',
#  'residual_VGLUT1_PSD95_CA1_SLM_overlap_um2',
#  'residual_VGLUT1_PSD95_CA3_SO_presynapse_image_mfi',
#  'residual_VGLUT1_PSD95_CA3_SO_pre_staining_area_um2',
#  'residual_VGLUT1_PSD95_CA3_SO_pre_puncta_density_per_100_um2',
#  'residual_VGLUT1_PSD95_CA3_SO_pre_mean_puncta_size_um2',
#  'residual_VGLUT1_PSD95_CA3_SO_postsynapse_image_mfi',
#  'residual_VGLUT1_PSD95_CA3_SO_post_staining_area_um2',
#  'residual_VGLUT1_PSD95_CA3_SO_post_puncta_density_per_100_um2',
#  'residual_VGLUT1_PSD95_CA3_SO_post_mean_puncta_size_um2',
#  'residual_VGLUT1_PSD95_CA3_SO_local_peak_colocalized_spots',
#  'residual_VGLUT1_PSD95_CA3_SO_pearson_cor',
#  'residual_VGLUT1_PSD95_CA3_SO_overlap_coeff',
#  'residual_VGLUT1_PSD95_CA3_SO_overlap_um2',
#  'residual_VGLUT1_PSD95_CA3_SL_presynapse_image_mfi',
#  'residual_VGLUT1_PSD95_CA3_SL_pre_staining_area_um2',
#  'residual_VGLUT1_PSD95_CA3_SL_pre_puncta_density_per_100_um2',
#  'residual_VGLUT1_PSD95_CA3_SL_pre_mean_puncta_size_um2',
#  'residual_VGLUT1_PSD95_CA3_SL_postsynapse_image_mfi',
#  'residual_VGLUT1_PSD95_CA3_SL_post_staining_area_um2',
#  'residual_VGLUT1_PSD95_CA3_SL_post_puncta_density_per_100_um2',
#  'residual_VGLUT1_PSD95_CA3_SL_post_mean_puncta_size_um2',
#  'residual_VGLUT1_PSD95_CA3_SL_local_peak_colocalized_spots',
#  'residual_VGLUT1_PSD95_CA3_SL_pearson_cor',
#  'residual_VGLUT1_PSD95_CA3_SL_overlap_coeff',
#  'residual_VGLUT1_PSD95_CA3_SL_overlap_um2',
#  'residual_VGLUT1_PSD95_CA3_SR_presynapse_image_mfi',
#  'residual_VGLUT1_PSD95_CA3_SR_pre_staining_area_um2',
#  'residual_VGLUT1_PSD95_CA3_SR_pre_puncta_density_per_100_um2',
#  'residual_VGLUT1_PSD95_CA3_SR_pre_mean_puncta_size_um2',
#  'residual_VGLUT1_PSD95_CA3_SR_postsynapse_image_mfi',
#  'residual_VGLUT1_PSD95_CA3_SR_post_staining_area_um2',
#  'residual_VGLUT1_PSD95_CA3_SR_post_puncta_density_per_100_um2',
#  'residual_VGLUT1_PSD95_CA3_SR_post_mean_puncta_size_um2',
#  'residual_VGLUT1_PSD95_CA3_SR_local_peak_colocalized_spots',
#  'residual_VGLUT1_PSD95_CA3_SR_pearson_cor',
#  'residual_VGLUT1_PSD95_CA3_SR_overlap_coeff',
#  'residual_VGLUT1_PSD95_CA3_SR_overlap_um2',
#  'residual_VGLUT1_PSD95_DG_ML_presynapse_image_mfi',
#  'residual_VGLUT1_PSD95_DG_ML_pre_staining_area_um2',
#  'residual_VGLUT1_PSD95_DG_ML_pre_puncta_density_per_100_um2',
#  'residual_VGLUT1_PSD95_DG_ML_pre_mean_puncta_size_um2',
#  'residual_VGLUT1_PSD95_DG_ML_postsynapse_image_mfi',
#  'residual_VGLUT1_PSD95_DG_ML_post_staining_area_um2',
#  'residual_VGLUT1_PSD95_DG_ML_post_puncta_density_per_100_um2',
#  'residual_VGLUT1_PSD95_DG_ML_post_mean_puncta_size_um2',
#  'residual_VGLUT1_PSD95_DG_ML_local_peak_colocalized_spots',
#  'residual_VGLUT1_PSD95_DG_ML_pearson_cor',
#  'residual_VGLUT1_PSD95_DG_ML_overlap_coeff',
#  'residual_VGLUT1_PSD95_DG_ML_overlap_um2',
#  'residual_VGLUT1_PSD95_DG_Hilus_presynapse_image_mfi',
#  'residual_VGLUT1_PSD95_DG_Hilus_pre_staining_area_um2',
#  'residual_VGLUT1_PSD95_DG_Hilus_pre_puncta_density_per_100_um2',
#  'residual_VGLUT1_PSD95_DG_Hilus_pre_mean_puncta_size_um2',
#  'residual_VGLUT1_PSD95_DG_Hilus_postsynapse_image_mfi',
#  'residual_VGLUT1_PSD95_DG_Hilus_post_staining_area_um2',
#  'residual_VGLUT1_PSD95_DG_Hilus_post_puncta_density_per_100_um2',
#  'residual_VGLUT1_PSD95_DG_Hilus_post_mean_puncta_size_um2',
#  'residual_VGLUT1_PSD95_DG_Hilus_local_peak_colocalized_spots',
#  'residual_VGLUT1_PSD95_DG_Hilus_pearson_cor',
#  'residual_VGLUT1_PSD95_DG_Hilus_overlap_coeff',
#  'residual_VGLUT1_PSD95_DG_Hilus_overlap_um2',
#  'residual_VGAT_GEPH_CA1_SO_presynapse_image_mfi',
#  'residual_VGAT_GEPH_CA1_SO_pre_staining_area_um2',
#  'residual_VGAT_GEPH_CA1_SO_pre_puncta_density_per_100_um2',
#  'residual_VGAT_GEPH_CA1_SO_pre_mean_puncta_size_um2',
#  'residual_VGAT_GEPH_CA1_SO_postsynapse_image_mfi',
#  'residual_VGAT_GEPH_CA1_SO_post_staining_area_um2',
#  'residual_VGAT_GEPH_CA1_SO_post_puncta_density_per_100_um2',
#  'residual_VGAT_GEPH_CA1_SO_post_mean_puncta_size_um2',
#  'residual_VGAT_GEPH_CA1_SO_local_peak_colocalized_spots',
#  'residual_VGAT_GEPH_CA1_SO_pearson_cor',
#  'residual_VGAT_GEPH_CA1_SO_overlap_coeff',
#  'residual_VGAT_GEPH_CA1_SO_overlap_um2',
#  'residual_VGAT_GEPH_CA1_SR_presynapse_image_mfi',
#  'residual_VGAT_GEPH_CA1_SR_pre_staining_area_um2',
#  'residual_VGAT_GEPH_CA1_SR_pre_puncta_density_per_100_um2',
#  'residual_VGAT_GEPH_CA1_SR_pre_mean_puncta_size_um2',
#  'residual_VGAT_GEPH_CA1_SR_postsynapse_image_mfi',
#  'residual_VGAT_GEPH_CA1_SR_post_staining_area_um2',
#  'residual_VGAT_GEPH_CA1_SR_post_puncta_density_per_100_um2',
#  'residual_VGAT_GEPH_CA1_SR_post_mean_puncta_size_um2',
#  'residual_VGAT_GEPH_CA1_SR_local_peak_colocalized_spots',
#  'residual_VGAT_GEPH_CA1_SR_pearson_cor',
#  'residual_VGAT_GEPH_CA1_SR_overlap_coeff',
#  'residual_VGAT_GEPH_CA1_SR_overlap_um2',
#  'residual_VGAT_GEPH_CA1_SLM_presynapse_image_mfi',
#  'residual_VGAT_GEPH_CA1_SLM_pre_staining_area_um2',
#  'residual_VGAT_GEPH_CA1_SLM_pre_puncta_density_per_100_um2',
#  'residual_VGAT_GEPH_CA1_SLM_pre_mean_puncta_size_um2',
#  'residual_VGAT_GEPH_CA1_SLM_postsynapse_image_mfi',
#  'residual_VGAT_GEPH_CA1_SLM_post_staining_area_um2',
#  'residual_VGAT_GEPH_CA1_SLM_post_puncta_density_per_100_um2',
#  'residual_VGAT_GEPH_CA1_SLM_post_mean_puncta_size_um2',
#  'residual_VGAT_GEPH_CA1_SLM_local_peak_colocalized_spots',
#  'residual_VGAT_GEPH_CA1_SLM_pearson_cor',
#  'residual_VGAT_GEPH_CA1_SLM_overlap_coeff',
#  'residual_VGAT_GEPH_CA1_SLM_overlap_um2',
#  'residual_VGAT_GEPH_CA3_SO_presynapse_image_mfi',
#  'residual_VGAT_GEPH_CA3_SO_pre_staining_area_um2',
#  'residual_VGAT_GEPH_CA3_SO_pre_puncta_density_per_100_um2',
#  'residual_VGAT_GEPH_CA3_SO_pre_mean_puncta_size_um2',
#  'residual_VGAT_GEPH_CA3_SO_postsynapse_image_mfi',
#  'residual_VGAT_GEPH_CA3_SO_post_staining_area_um2',
#  'residual_VGAT_GEPH_CA3_SO_post_puncta_density_per_100_um2',
#  'residual_VGAT_GEPH_CA3_SO_post_mean_puncta_size_um2',
#  'residual_VGAT_GEPH_CA3_SO_local_peak_colocalized_spots',
#  'residual_VGAT_GEPH_CA3_SO_pearson_cor',
#  'residual_VGAT_GEPH_CA3_SO_overlap_coeff',
#  'residual_VGAT_GEPH_CA3_SO_overlap_um2',
#  'residual_VGAT_GEPH_CA3_SL_presynapse_image_mfi',
#  'residual_VGAT_GEPH_CA3_SL_pre_staining_area_um2',
#  'residual_VGAT_GEPH_CA3_SL_pre_puncta_density_per_100_um2',
#  'residual_VGAT_GEPH_CA3_SL_pre_mean_puncta_size_um2',
#  'residual_VGAT_GEPH_CA3_SL_postsynapse_image_mfi',
#  'residual_VGAT_GEPH_CA3_SL_post_staining_area_um2',
#  'residual_VGAT_GEPH_CA3_SL_post_puncta_density_per_100_um2',
#  'residual_VGAT_GEPH_CA3_SL_post_mean_puncta_size_um2',
#  'residual_VGAT_GEPH_CA3_SL_local_peak_colocalized_spots',
#  'residual_VGAT_GEPH_CA3_SL_pearson_cor',
#  'residual_VGAT_GEPH_CA3_SL_overlap_coeff',
#  'residual_VGAT_GEPH_CA3_SL_overlap_um2',
#  'residual_VGAT_GEPH_CA3_SR_presynapse_image_mfi',
#  'residual_VGAT_GEPH_CA3_SR_pre_staining_area_um2',
#  'residual_VGAT_GEPH_CA3_SR_pre_puncta_density_per_100_um2',
#  'residual_VGAT_GEPH_CA3_SR_pre_mean_puncta_size_um2',
#  'residual_VGAT_GEPH_CA3_SR_postsynapse_image_mfi',
#  'residual_VGAT_GEPH_CA3_SR_post_staining_area_um2',
#  'residual_VGAT_GEPH_CA3_SR_post_puncta_density_per_100_um2',
#  'residual_VGAT_GEPH_CA3_SR_post_mean_puncta_size_um2',
#  'residual_VGAT_GEPH_CA3_SR_local_peak_colocalized_spots',
#  'residual_VGAT_GEPH_CA3_SR_pearson_cor',
#  'residual_VGAT_GEPH_CA3_SR_overlap_coeff',
#  'residual_VGAT_GEPH_CA3_SR_overlap_um2',
#  'residual_VGAT_GEPH_DG_ML_presynapse_image_mfi',
#  'residual_VGAT_GEPH_DG_ML_pre_staining_area_um2',
#  'residual_VGAT_GEPH_DG_ML_pre_puncta_density_per_100_um2',
#  'residual_VGAT_GEPH_DG_ML_pre_mean_puncta_size_um2',
#  'residual_VGAT_GEPH_DG_ML_postsynapse_image_mfi',
#  'residual_VGAT_GEPH_DG_ML_post_staining_area_um2',
#  'residual_VGAT_GEPH_DG_ML_post_puncta_density_per_100_um2',
#  'residual_VGAT_GEPH_DG_ML_post_mean_puncta_size_um2',
#  'residual_VGAT_GEPH_DG_ML_local_peak_colocalized_spots',
#  'residual_VGAT_GEPH_DG_ML_pearson_cor',
#  'residual_VGAT_GEPH_DG_ML_overlap_coeff',
#  'residual_VGAT_GEPH_DG_ML_overlap_um2',
#  'residual_VGAT_GEPH_DG_Hilus_presynapse_image_mfi',
#  'residual_VGAT_GEPH_DG_Hilus_pre_staining_area_um2',
#  'residual_VGAT_GEPH_DG_Hilus_pre_puncta_density_per_100_um2',
#  'residual_VGAT_GEPH_DG_Hilus_pre_mean_puncta_size_um2',
#  'residual_VGAT_GEPH_DG_Hilus_postsynapse_image_mfi',
#  'residual_VGAT_GEPH_DG_Hilus_post_staining_area_um2',
#  'residual_VGAT_GEPH_DG_Hilus_post_puncta_density_per_100_um2',
#  'residual_VGAT_GEPH_DG_Hilus_post_mean_puncta_size_um2',
#  'residual_VGAT_GEPH_DG_Hilus_local_peak_colocalized_spots',
#  'residual_VGAT_GEPH_DG_Hilus_pearson_cor',
#  'residual_VGAT_GEPH_DG_Hilus_overlap_coeff',
#  'residual_VGAT_GEPH_DG_Hilus_overlap_um2']

# %%
sample_hemispheres = [idx.split('_')[0] for idx in scaled_residuals_df.index]
sample_brain_ids = [idx.split('_')[1] for idx in scaled_residuals_df.index]

# create color mappings

# for Hemisphere
if protein == "VCAM1":
    hemisphere_color_map = {"LacZ-gRNA": "#c6c6c6", "VCAM1-gRNA": "#21a0e2"}
else:
    protein == "GPR37L1"
    hemisphere_color_map = {"LacZ-gRNA": "#c6c6c6", "GPR37L1-gRNA": "#e28d21"}

row_colors_hemisphere = [hemisphere_color_map[h] for h in sample_hemispheres]

# for BrainID (you have 'Brain-4', 'Brain-4-2', 'Brain-5', 'Brain-7')
unique_brain_ids = sorted(list(set(sample_brain_ids)))
brain_palette = sns.color_palette("Dark2", len(unique_brain_ids))
brain_color_map = {brain_id_str: brain_palette[i] for i, brain_id_str in enumerate(unique_brain_ids)}
row_colors_brain = [brain_color_map[b] for b in sample_brain_ids]

# combine into a DataFrame for clustermap's row_colors
row_colors_df = pd.DataFrame({
    'Hemisphere': row_colors_hemisphere,
    'BrainID': row_colors_brain
}, index=scaled_residuals_df.index)

# %%
g = sns.clustermap(
        scaled_residuals_df,
        method="weighted",      
        metric="correlation",    
        cmap= "PRGn",        
        row_colors=row_colors_df, 
        col_cluster=False,  
        row_cluster=True,   
        dendrogram_ratio=(.05, .2),
        cbar_pos=(1, .8, .02, .18), 
        # annot = True,
        # annot_kws={"size": 5},
        figsize=(20, 10) 
)

plt.show()
plt.suptitle('Heatmap of Brain-Adjusted Features', y=1.02, fontsize=16) # Title for the figure
plt.show()

# %%
selected_features_vcam1 = {
    "residual_VGLUT1_PSD95_CA1_SO_presynapse_image_mfi", 
    "residual_VGLUT1_PSD95_CA1_SR_presynapse_image_mfi",
    "residual_VGLUT1_PSD95_CA1_SLM_presynapse_image_mfi",
    "residual_VGLUT1_PSD95_CA3_SO_presynapse_image_mfi",
    "residual_VGLUT1_PSD95_CA3_SL_presynapse_image_mfi",
    "residual_VGLUT1_PSD95_CA3_SR_presynapse_image_mfi",
    "residual_VGLUT1_PSD95_DG_ML_presynapse_image_mfi",
    "residual_VGLUT1_PSD95_DG_Hilus_presynapse_image_mfi",

    "residual_VGLUT1_PSD95_CA1_SR_pre_staining_area_um2",
    "residual_VGLUT1_PSD95_DG_ML_pre_staining_area_um2",

    "residual_VGLUT1_PSD95_CA1_SR_pre_puncta_density_per_100_um2",
    "residual_VGLUT1_PSD95_DG_ML_pre_mean_puncta_size_um2",

    "residual_VGLUT1_PSD95_CA1_SO_postsynapse_image_mfi", 
    "residual_VGLUT1_PSD95_CA1_SLM_postsynapse_image_mfi",
    "residual_VGLUT1_PSD95_CA3_SL_postsynapse_image_mfi",
    "residual_VGLUT1_PSD95_CA3_SR_postsynapse_image_mfi",
    "residual_VGLUT1_PSD95_DG_Hilus_post_staining_area_um2",
    "residual_VGLUT1_PSD95_DG_Hilus_post_puncta_density_per_100_um2",

    "residual_VGLUT1_PSD95_CA1_SO_local_peak_colocalized_spots",
    "residual_VGLUT1_PSD95_CA1_SR_local_peak_colocalized_spots",
    "residual_VGLUT1_PSD95_CA1_SLM_local_peak_colocalized_spots",
    "residual_VGLUT1_PSD95_CA3_SO_local_peak_colocalized_spots",
    "residual_VGLUT1_PSD95_CA3_SL_local_peak_colocalized_spots",
    "residual_VGLUT1_PSD95_CA3_SR_local_peak_colocalized_spots",
    "residual_VGLUT1_PSD95_DG_ML_local_peak_colocalized_spots",

    "residual_VGLUT1_PSD95_DG_ML_overlap_coeff",
    "residual_VGLUT1_PSD95_CA1_SR_overlap_um2",
    "residual_VGLUT1_PSD95_DG_ML_overlap_um2",
    "residual_VGLUT1_PSD95_DG_Hilus_overlap_um2",


    "residual_VGAT_GEPH_CA1_SR_presynapse_image_mfi", 
    "residual_VGAT_GEPH_CA1_SLM_presynapse_image_mfi", 
    "residual_VGAT_GEPH_CA3_SR_presynapse_image_mfi", 
    "residual_VGAT_GEPH_DG_ML_presynapse_image_mfi", 

    "residual_VGAT_GEPH_CA1_SLM_pre_staining_area_um2",
    "residual_VGAT_GEPH_CA1_SLM_pre_puncta_density_per_100_um2",
    "residual_VGAT_GEPH_CA1_SLM_pre_mean_puncta_size_um2",

    "residual_VGAT_GEPH_CA3_SL_post_staining_area_um2",
    "residual_VGAT_GEPH_CA3_SL_post_puncta_density_per_100_um2",


    "residual_VGAT_GEPH_CA1_SR_local_peak_colocalized_spots",
    "residual_VGAT_GEPH_CA1_SLM_local_peak_colocalized_spots",
    "residual_VGAT_GEPH_DG_ML_local_peak_colocalized_spots",
} 

selected_features_gpr37l1 = {
    "residual_VGAT_GEPH_CA3_SL_post_staining_area_um2", 
    "residual_VGAT_GEPH_CA3_SL_post_puncta_density_per_100_um2",
} 

if protein ==  "VCAM1":
    selected_features = selected_features_vcam1
elif protein == "GPR37L1":
    selected_features = selected_features_gpr37l1

# %%
selected_features
# Out:
# {'residual_VGAT_GEPH_CA3_SL_post_puncta_density_per_100_um2',
#  'residual_VGAT_GEPH_CA3_SL_post_staining_area_um2'}

# %%
g = sns.clustermap(
    scaled_residuals_df,
    method="weighted",
    metric="correlation",
    cmap="PRGn",
    row_colors=row_colors_df,
    col_cluster=False,
    row_cluster=True,
    dendrogram_ratio=(.05, .2),
    cbar_pos=(1, .8, .02, .18),
    figsize=(20, 6)
)

clustered_cols = list(g.data2d.columns)

# positions of selected features in clustered order
sel_pos = [i for i, c in enumerate(clustered_cols) if c in selected_features]
sel_labels = [clustered_cols[i] for i in sel_pos]

ax = g.ax_heatmap

# set ONLY these ticks + labels
ax.set_xticks(sel_pos)
ax.set_xticklabels(sel_labels, rotation=90, fontsize=9)

# remove the little minor ticks that seaborn/matplotlib may add
ax.tick_params(axis="x", which="minor", bottom=False)
ax.tick_params(axis="x", which="major", bottom=True, length=4)

# give labels breathing room
g.fig.subplots_adjust(bottom=0.30)

# adjust dendrogram line thickness 
lw = 1.5 

for ax in [g.ax_row_dendrogram, g.ax_col_dendrogram]:
    # seaborn draws dendrograms as LineCollections
    for coll in ax.collections:
        coll.set_linewidth(lw)
    # sometimes there are also plain Line2D objects
    for line in ax.lines:
        line.set_linewidth(lw)

plt.savefig(f"{protein}_residuals_heatmap_plot.svg", format='svg')
plt.show()
