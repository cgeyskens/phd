# %%
# test-file-2.ipynb

from pathlib import Path
import czifile
import pandas as pd
import os
from microfilm.microplot import microshow
import numpy as np

# defining the input_folder and output_folder
input_folder = "/mnt/d/code/phd/image-analysis/synapse-counting/test-images-VLGUT1-PSD95/"
output_folder = "/mnt/d/code/phd/image-analysis/synapse-counting/output_data/"

# get a list of files in that input_folder
file_list = os.listdir(input_folder)
file_list
# Out:
# ['OE_Exp1_IHC_Exp1_HA-GPR37L1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA1_SO.czi',
#  'OE_Exp1_IHC_Exp1_HA-GPR37L1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA1_SO_2.czi',
#  'OE_Exp1_IHC_Exp1_HA-GPR37L1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA1_SR_1.czi',
#  'OE_Exp1_IHC_Exp1_HA-GPR37L1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA1_SR_2.czi',
#  'OE_Exp1_IHC_Exp1_HA-GPR37L1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA3_SL_1.czi',
#  'OE_Exp1_IHC_Exp1_HA-GPR37L1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA3_SL_2.czi',
#  'OE_Exp1_IHC_Exp1_HA-GPR37L1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA3_SO_1.czi',
#  'OE_Exp1_IHC_Exp1_HA-GPR37L1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA3_SO_2.czi',
#  'OE_Exp1_IHC_Exp1_HA-GPR37L1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA3_SR_1.czi',
#  'OE_Exp1_IHC_Exp1_HA-GPR37L1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA3_SR_2.czi',
#  'OE_Exp1_IHC_Exp1_HA-VCAM1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA1_SO_1.czi',
#  'OE_Exp1_IHC_Exp1_HA-VCAM1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA1_SO_2.czi',
#  'OE_Exp1_IHC_Exp1_HA-VCAM1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA1_SR_1.czi',
#  'OE_Exp1_IHC_Exp1_HA-VCAM1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA1_SR_2.czi',
#  'OE_Exp1_IHC_Exp1_HA-VCAM1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA3_SL_1.czi',
#  'OE_Exp1_IHC_Exp1_HA-VCAM1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA3_SL_2.czi',
#  'OE_Exp1_IHC_Exp1_HA-VCAM1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA3_SO_1.czi',
#  'OE_Exp1_IHC_Exp1_HA-VCAM1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA3_SO_2.czi',
#  'OE_Exp1_IHC_Exp1_HA-VCAM1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA3_SR_1.czi',
#  'OE_Exp1_IHC_Exp1_HA-VCAM1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA3_SR_2.czi',
#  'OE_Exp1_IHC_Exp1_HA-VCAM1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_Cortex_1.czi',
#  'OE_Exp1_IHC_Exp1_HA-VCAM1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_Cortex_2.czi']

# %%
def process(filename):
    
    # getting the mean intensity of the image
    image = czifile.imread(filename)
    intensity = np.mean(image)
    
    return intensity

# %%
# getting the intensities in each file
intensities = [process(input_folder + file) for file in file_list]
intensities
# Out:
# [765.623218,
#  568.3781145,
#  652.719682,
#  659.73186,
#  712.2684675,
#  777.9894195,
#  903.3598845,
#  872.083508,
#  529.1345885,
#  549.53524,
#  659.8088695,
#  692.5655765,
#  670.7173995,
#  697.6412775,
#  577.106802,
#  573.2466685,
#  703.753941,
#  829.1705075,
#  653.3204375,
#  527.4608325,
#  409.301241,
#  391.8160655]

# %%
# getting the right filenames

def image_filename(filename):
    
    # get the filename
    name_of_file = os.path.splitext(os.path.basename(filename))[0]
    split_filename = name_of_file.split("_")

    # get only the experimental parameters from the filename
    index_nums = [0, 1, 2, 3, 10, 11] # the indexes of the elements that I would like to extract fro; the filename
    desired_parts = [split_filename[val] for val in index_nums]
    desired_filename = "_".join(desired_parts)
    
    return desired_filename

# %%
filenames = [image_filename(input_folder + file) for file in file_list]
filenames
# Out:
# ['OE_Exp1_IHC_Exp1_CA1_SO',
#  'OE_Exp1_IHC_Exp1_CA1_SO',
#  'OE_Exp1_IHC_Exp1_CA1_SR',
#  'OE_Exp1_IHC_Exp1_CA1_SR',
#  'OE_Exp1_IHC_Exp1_CA3_SL',
#  'OE_Exp1_IHC_Exp1_CA3_SL',
#  'OE_Exp1_IHC_Exp1_CA3_SO',
#  'OE_Exp1_IHC_Exp1_CA3_SO',
#  'OE_Exp1_IHC_Exp1_CA3_SR',
#  'OE_Exp1_IHC_Exp1_CA3_SR',
#  'OE_Exp1_IHC_Exp1_CA1_SO',
#  'OE_Exp1_IHC_Exp1_CA1_SO',
#  'OE_Exp1_IHC_Exp1_CA1_SR',
#  'OE_Exp1_IHC_Exp1_CA1_SR',
#  'OE_Exp1_IHC_Exp1_CA3_SL',
#  'OE_Exp1_IHC_Exp1_CA3_SL',
#  'OE_Exp1_IHC_Exp1_CA3_SO',
#  'OE_Exp1_IHC_Exp1_CA3_SO',
#  'OE_Exp1_IHC_Exp1_CA3_SR',
#  'OE_Exp1_IHC_Exp1_CA3_SR',
#  'OE_Exp1_IHC_Exp1_Cortex_1',
#  'OE_Exp1_IHC_Exp1_Cortex_2']

# %%
# merging into df
d = {"image_names": filenames, "intensities": intensities}
df = pd.DataFrame(d).set_index("image_names")

# writing the df out into a csv
output_filename = "test" + ".csv"
output_path = output_folder + output_filename
df.to_csv(output_path)
