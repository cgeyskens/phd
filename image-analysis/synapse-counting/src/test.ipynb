# %%
from image_metadata import ProcessImageMetaData

# %%
path = "/Volumes/KINGSTON/code/phd/image-analysis/synapse-counting/test-images-VLGUT1-PSD95-A/OE_Exp1_IHC_Exp1_HA-GPR37L1_555-VGLUT1_647-PSD95_63X_airyscan_1.8zoom_CA1_SO.czi"
processor = ProcessImageMetaData(path)
processor.image_filename([0, 1, 2, 3, 7, 11])
# Out:
# 'OE_Exp1_IHC_Exp1_63X_SO'

# %%
# get the filename
name_of_file = os.path.splitext(os.path.basename(path))[0]
split_filename = name_of_file.split("_")

print(name_of_file)

# get only the experimental parameters from the filename
index_nums = [0, 1, 2, 3, 10, 11] # the indexes of the elements that I would like to extract from
desired_parts = [split_filename[val] for val in index_nums]
desired_filename = "_".join(desired_parts)

print(desired_filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # get the filename
# ----> 2 name_of_file = os.path.splitext(os.path.basename(path))[0]
#       3 split_filename = name_of_file.split("_")
#       5 print(name_of_file)
#
# NameError: name 'os' is not defined
